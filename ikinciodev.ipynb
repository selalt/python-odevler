# %%
#ödev1

maas = float(input("Lütfen maaşınızı giriniz: "))
if maas <= 10000 :
    vergi = maas*0.05

elif maas <= 25000 :
    vergi = maas*0.10

elif maas <= 45000 :
    vergi = maas*0.25

else :
    vergi = maas*0.30

yeni_maas= maas - vergi
print ( "Vergi düşülmüş şekilde alacağınız maaş : " , yeni_maas)
# Out:
# Lütfen maaşınızı giriniz:  10000
# Vergi düşülmüş şekilde alacağınız maaş :  9500.0

# %%
#ödev2

kullanici_adi = input("Lütfen bir kullanıcı adı giriniz: ")
sifre = input("Şifre oluşturunuz: ")

if len(sifre) >= 6 :
    print("Hesabınız oluşturuldu.")
else :
    print("Şifreniz en az 6 haneli olmalıdır.")
# Out:
# Lütfen bir kullanıcı adı giriniz:  Selin
# Şifre oluşturunuz:  123456
# Hesabınız oluşturuldu.

# %%
#ödev3

while True:
    kullanici_adi = input("Lütfen bir kullanıcı adı giriniz: ")
    sifre = input("Şifre oluşturunuz: ")

    if len(sifre) >= 5 and len(sifre) <= 10 :
        print("Hesabınız oluşturuldu.")
        break
    else :
        print("Şifreniz en az 5, en fazla 10 haneli olmalıdır.")
# Out:
# Lütfen bir kullanıcı adı giriniz:  Selin
# Şifre oluşturunuz:  123456789456123
# Şifreniz en az 5, en fazla 10 haneli olmalıdır.
# Lütfen bir kullanıcı adı giriniz:  Selin
# Şifre oluşturunuz:  123456
# Hesabınız oluşturuldu.

# %%
#ödev4
#kullanıcı adının doğru girildiğini varsayarak devam ediyoruz sanırım.

dogru_sifre = "1234"

hak = 3

while hak > 0 :
    girilen_sifre = input("Şifrenizi giriniz: ")

    if girilen_sifre == dogru_sifre :
        print("Giriş yapıldı.")
        break

    else :
        hak -=1
        if hak == 0 :
            print ("3 yanlış şifre girdiniz, 24 saat sonra tekrar deneyin!")
        else :
            print("Yanlış şifre girdiniz, kalan hakkınız: ", hak)
# Out:
# Şifrenizi giriniz:  1243
# Yanlış şifre girdiniz, kalan hakkınız:  2
# Şifrenizi giriniz:  1234
# Giriş yapıldı.
