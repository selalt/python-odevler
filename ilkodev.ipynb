# %%
#ödev1

sayi = 17
sayi_str = str(sayi)
sayi_float = float(sayi)

yazi = "33"
yazi_int = int(yazi)
yazi_float = int(yazi)

print(type(sayi_str), type(sayi_float), type(yazi_int), type(yazi_float))
# Out:
# <class 'str'> <class 'float'> <class 'int'> <class 'int'>

# %%
#ödev2
Ayse = 17
Ali = 19
Salih = 25

if Ayse == Ali :
    print( "Ali ve Ayşe'nin yaşları eşit")

if Ali != Salih :
    print("Salih ve Ali'nin yaşları eşit değil")
# Out:
# Salih ve Ali'nin yaşları eşit değil

# %%
#ödev3
a = float(input("Birinci sayıyı giriniz: "))
b = float(input("İkinci sayıyı giriniz: "))

print( "Toplama: ", a+b )
print( "Çıkarma: ", a-b )
print( "Çarpma: ", a*b )
print( "Bölme: ", a/b )
# Out:
# Birinci sayıyı giriniz:  50
# İkinci sayıyı giriniz:  10
# Toplama:  60.0
# Çıkarma:  40.0
# Çarpma:  500.0
# Bölme:  5.0

# %%
#ödev4

ad = input( " Adınız : ")
yas = input( " Yaşınız : ")
sehir = input( " Yaşadığınız şehir : ")
meslek = input( " Mesleğiniz : ")

print( " Adınız : ", ad )
print( " Yaşınız : ", yas)
print( " Yaşadığınız şehir : ", sehir)
print( " Mesleğiniz : ", meslek)
# Out:
#  Adınız :  Füsun
#  Yaşınız :  19
#  Yaşadığınız şehir :  Ankara
#  Mesleğiniz :  Öğrenci
#  Adınız :  Füsun
#  Yaşınız :  19
#  Yaşadığınız şehir :  Ankara
#  Mesleğiniz :  Öğrenci

# %%
#ödev5

ifade = " Hi-Kod Veri Bilimi Atölyesi"
kelimeler = ifade.split()

print(kelimeler[0])
print(kelimeler[1])
print(kelimeler[2])
print(kelimeler[3])
# Out:
# Hi-Kod
# Veri
# Bilimi
# Atölyesi

# %%
buyuk_harf_ile_ifade = ifade.upper()

print(buyuk_harf_ile_ifade)
# Out:
#  HI-KOD VERI BILIMI ATÖLYESI

# %%
kucuk_harf_ile_ifade = ifade.lower()

print(kucuk_harf_ile_ifade)
# Out:
#  hi-kod veri bilimi atölyesi

# %%
rakamlar = "0123456789"

cift = "".join([x for x in rakamlar if int(x)%2==0 ])
tek = "".join([x for x in rakamlar if int(x)%2 !=0 ])

print(cift)
print(tek)
# Out:
# 02468
# 13579
